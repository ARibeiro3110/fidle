# %% [markdown]
# <img width="800px" src="../fidle/img/header.svg"></img>
#
# # <!-- TITLE --> [K3MNIST1] - Simple classification with DNN
# <!-- DESC --> An example of classification using a dense neural network for the famous MNIST dataset
# <!-- AUTHOR : Jean-Luc Parouty (CNRS/SIMaP) -->
#
# ## Objectives :
#  - Recognizing handwritten numbers
#  - Understanding the principle of a classifier DNN network
#  - Implementation with Keras
#
#
# The [MNIST dataset](http://yann.lecun.com/exdb/mnist/) (Modified National Institute of Standards and Technology) is a must for Deep Learning.
# It consists of 60,000 small images of handwritten numbers for learning and 10,000 for testing.
#
#
# ## What we're going to do :
#
#  - Retrieve data
#  - Preparing the data
#  - Create a model
#  - Train the model
#  - Evaluate the result

# %% [markdown]
# ## Step 1 - Init python stuff

# %%
import os
os.environ['KERAS_BACKEND'] = 'torch'

import keras

import numpy as np
import matplotlib.pyplot as plt
import sys,os
from importlib import reload

# Init Fidle environment
import fidle

run_id, run_dir, datasets_dir = fidle.init('K3MNIST1')
# Out:
# <style>
#
# div.warn {
#     background-color: #fcf2f2;
#     border-color: #dFb5b4;
#     border-left: 5px solid #dfb5b4;
#     padding: 0.5em;
#     font-weight: bold;
#     font-size: 1.1em;;
#     }
#
#
#
# div.nota {
#     background-color: #DAFFDE;
#     border-left: 5px solid #92CC99;
#     padding: 0.5em;
#     }
#
# div.todo:before { content:url(data:image/svg+xml;base64,...);
#     float:left;
#     margin-right:20px;
#     margin-top:-20px;
#     margin-bottom:20px;
# }
# div.todo{
#     font-weight: bold;
#     font-size: 1.1em;
#     margin-top:40px;
# }
# div.todo ul{
#     margin: 0.2em;
# }
# div.todo li{
#     margin-left:60px;
#     margin-top:0;
#     margin-bottom:0;
# }
#
# div .comment{
#     font-size:0.8em;
#     color:#696969;
# }
#
#
#
# </style>
# <br>**FIDLE - Environment initialization**
# Version              : 2.3.2
# Run id               : K3MNIST1
# Run dir              : ./run/K3MNIST1
# Datasets dir         : /data/datasets-fidle
# Start time           : 03/07/24 11:22:52
# Hostname             : ebf2030c9b9e (Linux)
# Tensorflow log level : Info + Warning + Error  (=0)
# Update keras cache   : False
# Update torch cache   : False
# Save figs            : ./run/K3MNIST1/figs (False)
# keras                : 3.0.5
# numpy                : 1.26.4
# sklearn              : 1.4.1.post1
# yaml                 : 6.0.1
# matplotlib           : 3.8.3
# pandas               : 2.2.1
# torch                : 2.2.1+cpu

# %% [markdown]
# Verbosity during training : 0 = silent, 1 = progress bar, 2 = one line per epoch

# %%
fit_verbosity = 1

# %% [markdown]
# Override parameters (batch mode) - Just forget this cell

# %%
fidle.override('fit_verbosity')

# %% [markdown]
# ## Step 2 - Retrieve data
# MNIST is one of the most famous historic dataset.
# Include in [Keras datasets](https://keras.io/datasets)

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

print("x_train : ",x_train.shape)
print("y_train : ",y_train.shape)
print("x_test  : ",x_test.shape)
print("y_test  : ",y_test.shape)
# Out:
# x_train :  (60000, 28, 28)
# y_train :  (60000,)
# x_test  :  (10000, 28, 28)
# y_test  :  (10000,)

# %% [markdown]
# ## Step 3 - Preparing the data

# %%
print('Before normalization : Min={}, max={}'.format(x_train.min(),x_train.max()))

xmax=x_train.max()
x_train = x_train / xmax
x_test  = x_test  / xmax

print('After normalization  : Min={}, max={}'.format(x_train.min(),x_train.max()))
# Out:
# Before normalization : Min=0, max=255
# After normalization  : Min=0.0, max=1.0

# %% [markdown]
# ### Have a look

# %%
fidle.scrawler.images(x_train, y_train, [27],  x_size=5,y_size=5, colorbar=True, save_as='01-one-digit')
fidle.scrawler.images(x_train, y_train, range(5,41), columns=12, save_as='02-many-digits')

# %% [markdown]
# ## Step 4 - Create model
# About informations about :
#  - [Optimizer](https://keras.io/api/optimizers)
#  - [Activation](https://keras.io/api/layers/activations)
#  - [Loss](https://keras.io/api/losses)
#  - [Metrics](https://keras.io/api/metrics)

# %%
hidden1     = 100
hidden2     = 100

model = keras.Sequential([
    keras.layers.Input((28,28)),
    keras.layers.Flatten(),
    keras.layers.Dense( hidden1, activation='relu'),
    keras.layers.Dense( hidden2, activation='relu'),
    keras.layers.Dense( 10,      activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Step 5 - Train the model

# %%
batch_size  = 512
epochs      =  16

history = model.fit(  x_train, y_train,
                      batch_size      = batch_size,
                      epochs          = epochs,
                      verbose         = fit_verbosity,
                      validation_data = (x_test, y_test))
# Out:
# Epoch 1/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7161 - loss: 1.0303 - val_accuracy: 0.9277 - val_loss: 0.2529
# Epoch 2/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.9328 - loss: 0.2326 - val_accuracy: 0.9504 - val_loss: 0.1746
# Epoch 3/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.9514 - loss: 0.1664 - val_accuracy: 0.9590 - val_loss: 0.1452
# Epoch 4/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9621 - loss: 0.1327 - val_accuracy: 0.9630 - val_loss: 0.1270
# Epoch 5/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9702 - loss: 0.1069 - val_accuracy: 0.9668 - val_loss: 0.1139
# Epoch 6/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9746 - loss: 0.0878 - val_accuracy: 0.9700 - val_loss: 0.1049
# Epoch 7/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9784 - loss: 0.0737 - val_accuracy: 0.9715 - val_loss: 0.1008
# Epoch 8/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9818 - loss: 0.0659 - val_accuracy: 0.9715 - val_loss: 0.1014
# Epoch 9/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9841 - loss: 0.0566 - val_accuracy: 0.9737 - val_loss: 0.0895
# Epoch 10/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9861 - loss: 0.0498 - val_accuracy: 0.9735 - val_loss: 0.0925
# Epoch 11/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9861 - loss: 0.0489 - val_accuracy: 0.9762 - val_loss: 0.0839
# Epoch 12/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9900 - loss: 0.0376 - val_accuracy: 0.9768 - val_loss: 0.0834
# Epoch 13/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9895 - loss: 0.0378 - val_accuracy: 0.9754 - val_loss: 0.0854
# Epoch 14/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9908 - loss: 0.0325 - val_accuracy: 0.9772 - val_loss: 0.0818
# Epoch 15/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9924 - loss: 0.0288 - val_accuracy: 0.9769 - val_loss: 0.0826
# Epoch 16/16
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9943 - loss: 0.0227 - val_accuracy: 0.9778 - val_loss: 0.0850

# %% [markdown]
# ## Step 6 - Evaluate
# ### 6.1 - Final loss and accuracy

# %%
score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss     :', score[0])
print('Test accuracy :', score[1])
# Out:
# Test loss     : 0.0827798917889595
# Test accuracy : 0.9778000116348267

# %% [markdown]
# ### 6.2 - Plot history

# %%
fidle.scrawler.history(history, figsize=(6,4), save_as='03-history')

# %% [markdown]
# ### 6.3 - Plot results

# %%
#y_pred   = model.predict_classes(x_test)           Deprecated after 01/01/2021 !!

y_sigmoid = model.predict(x_test, verbose=fit_verbosity)
y_pred    = np.argmax(y_sigmoid, axis=-1)

fidle.scrawler.images(x_test, y_test, range(0,200), columns=12, x_size=1, y_size=1, y_pred=y_pred, save_as='04-predictions')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %% [markdown]
# ### 6.4 - Plot some errors

# %%
errors=[ i for i in range(len(x_test)) if y_pred[i]!=y_test[i] ]
errors=errors[:min(24,len(errors))]
fidle.scrawler.images(x_test, y_test, errors[:15], columns=6, x_size=2, y_size=2, y_pred=y_pred, save_as='05-some-errors')

# %%
fidle.scrawler.confusion_matrix(y_test,y_pred,range(10),normalize=True, save_as='06-confusion-matrix')

# %%
fidle.end()
# Out:
# **End time :** 03/07/24 11:24:10
# **Duration :** 00:01:17 223ms
# This notebook ends here :-)
# [https://fidle.cnrs.fr](https://fidle.cnrs.fr)

# %% [markdown]
# <div class="todo">
#     A few things you can do for fun:
#     <ul>
#         <li>Changing the network architecture (layers, number of neurons, etc.)</li>
#         <li>Display a summary of the network</li>
#         <li>Retrieve and display the softmax output of the network, to evaluate its "doubts".</li>
#     </ul>
# </div>

# %% [markdown]
# ---
# <img width="80px" src="../fidle/img/logo-paysage.svg"></img>
